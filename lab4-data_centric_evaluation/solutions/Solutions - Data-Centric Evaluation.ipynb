# %% [markdown]
# # Lab - Data-Centric Evaluation of ML Models
#
# This lab is intended to accompany the lecture on Data-Centric Evaluation of ML Models. In this lab, you are given a training dataset and your goal is to improve the dataset in order to boost the accuracy of a fixed classification model on a given (fixed) test dataset. Reviewing the lecture notes will be helpful to get some ideas.
#
# You can get all the dependencies you need for this notebook by running:

# %%
# !pip install cleanlab matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: cleanlab in E:\anaconda\envs\dcai\Lib\site-packages (2.9.0)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/9.3 MB 4.2 MB/s eta 0:00:03
#      ------ --------------------------------- 1.6/9.3 MB 3.8 MB/s eta 0:00:03
#      ---------- ----------------------------- 2.4/9.3 MB 3.8 MB/s eta 0:00:02
#      ------------ --------------------------- 2.9/9.3 MB 3.8 MB/s eta 0:00:02
#      ---------------- ----------------------- 3.9/9.3 MB 3.9 MB/s eta 0:00:02
#      -------------------- ------------------- 4.7/9.3 MB 3.9 MB/s eta 0:00:02
#      ------------------------ --------------- 5.8/9.3 MB 4.0 MB/s eta 0:00:01
#      ----------------------------- ---------- 6.8/9.3 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 8.1/9.3 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 9.3/9.3 MB 4.4 MB/s  0:00:02
# Requirement already satisfied: numpy>=1.22 in E:\anaconda\envs\dcai\Lib\site-packages (from cleanlab) (2.5.3)
# Requirement already satisfied: scikit-learn>=1.1 in E:\anaconda\envs\dcai\Lib\site-packages (from cleanlab) (1.9.0)
# Requirement already satisfied: tqdm>=4.53.0 in E:\anaconda\envs\dcai\Lib\site-packages (from cleanlab) (4.70.0)
# Requirement already satisfied: pandas>=1.4.0 in E:\anaconda\envs\dcai\Lib\site-packages (from cleanlab) (3.0.5)
# Requirement already satisfied: termcolor>=2.4.0 in E:\anaconda\envs\dcai\Lib\site-packages (from cleanlab) (3.3.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.65.0-cp312-cp312-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ------------------------- -------------- 1.6/2.5 MB 7.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 6.5 MB/s  0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Requirement already satisfied: packaging>=20.0 in E:\anaconda\envs\dcai\Lib\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Requirement already satisfied: python-dateutil>=2.7 in E:\anaconda\envs\dcai\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in E:\anaconda\envs\dcai\Lib\site-packages (from pandas>=1.4.0->cleanlab) (2026.3)
# Requirement already satisfied: six>=1.5 in E:\anaconda\envs\dcai\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: scipy>=1.10.0 in E:\anaconda\envs\dcai\Lib\site-packages (from scikit-learn>=1.1->cleanlab) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in E:\anaconda\envs\dcai\Lib\site-packages (from scikit-learn>=1.1->cleanlab) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in E:\anaconda\envs\dcai\Lib\site-packages (from scikit-learn>=1.1->cleanlab) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in E:\anaconda\envs\dcai\Lib\site-packages (from scikit-learn>=1.1->cleanlab) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in E:\anaconda\envs\dcai\Lib\site-packages (from joblib>=1.4.0->scikit-learn>=1.1->cleanlab) (3.1.2)
# Requirement already satisfied: colorama in E:\anaconda\envs\dcai\Lib\site-packages (from tqdm>=4.53.0->cleanlab) (0.4.6)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------- ----------------- 4/7 [cycler]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2

# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import balanced_accuracy_score

import matplotlib.pyplot as plt

# %%
SEED = 123
np.random.seed(SEED)  # for reproducibility

# %% [markdown]
# # Load dataset
#
# The data come from a 3-class classification task where the goal is to predict `y` based on features `x1`, ..., `x5`.
# We convert the data to a numpy array format.

# %%
df = pd.read_csv("../train.csv")
df_test = pd.read_csv("../test.csv")

# %%
df.head()
# Out:
#          x0        x1        x2        x3        x4     x5  y
# 0 -0.333489 -0.770208 -2.697486 -0.628563 -1.277720  100.0  2
# 1 -0.787124  1.230800  1.415472 -0.805927  0.175115  100.0  1
# 2  0.781197 -0.856227  2.138879  2.495417  0.868192  100.0  1
# 3  1.895093 -0.885939  1.946352 -2.082747  0.064914  100.0  1
# 4  0.689091 -5.091299 -2.218682  0.330767  3.012755  100.0  2

# %%
df_test.head()
# Out:
#          x0        x1        x2        x3        x4     x5  y
# 0  2.337701 -0.681121  1.883774  0.949812 -0.311507 -100.0  1
# 1  1.101249 -2.032961  0.344490  0.724925  1.355534 -100.0  2
# 2  1.791349 -2.808856 -1.409471  0.552069  0.433901  100.0  2
# 3  2.082599  0.811498  0.906920 -0.749352  1.974424 -100.0  2
# 4  1.214627 -0.448392  1.812024  0.429543  0.396450 -100.0  1

# %%
y = df["y"].values
df.drop(columns=["y"], inplace=True)
X = df.values

y_test = df_test["y"].values
df_test.drop(columns=["y"], inplace=True)
X_test = df_test.values

print(X)
print(y)
# Out:
# [[  -0.33348927   -0.7702077    -2.69748604   -0.62856274   -1.27772042
#    100.        ]
#  [  -0.7871239     1.23080016    1.41547226   -0.8059272     0.1751147
#    100.        ]
#  [   0.78119711   -0.85622725    2.13887864    2.49541712    0.86819164
#    100.        ]
#  ...
#  [   1.19101444   -1.72465036   -1.17854745   -1.54881816   -1.51740071
#   -100.        ]
#  [  -2.03358571   -0.23977122    1.21509471    0.86023614    0.69816843
#    100.        ]
#  [   0.15125519   -1.21711969    2.77498591    0.7090941     0.89159205
#   -100.        ]]
# [2 1 1 ... 2 1 1]

# %% [markdown]
# Here's a simple plot of the first two features, colored by class. Visualizing the dataset may be helpful to you in this assignment, but can be tricky with 6-dimensional features!

# %%
plt.scatter(X[:,0], X[:,1], c=list(y))

# %% [markdown]
# # Improve ML Model via data-centric techniques

# %% [markdown]
# We train a simple neural network model (Multi-Layer Perceptron classifier) and evaluate it on the given test set.
# Note that the evaluation metric used is `balanced_accuracy`. This is the accuracy amongst all examples in a given class, averaged over all classes, which better represents performance on minority classes.
#
# You should never change the test data labels `y_test` in this lab, nor the neural network model. You may change the training data `X`, `y` as you see fit, and update `X_test` accordingly so your model is able to make predictions on it.

# %%
def train_evaluate_model(X, y, X_test, y_test):
    model = MLPClassifier(early_stopping=True, random_state=SEED)
    model.fit(X, y)
    predictions = model.predict(X_test)
    acc = balanced_accuracy_score(y_true=y_test, y_pred=predictions)
    print(f"Balanced accuracy = {acc}")
    return predictions

# %% [markdown]
# A baseline version of the model is trained on the original given data:

# %%
predictions = train_evaluate_model(X, y, X_test, y_test)
# Out:
# Balanced accuracy = 0.5759397707696671

# %% [markdown]
# # Exercise
#
# Your goal is to produce a version of this same model that has much better test accuracy!
# You should accomplish this by changing `X` and `y` as you see fit. Consider various ideas presented in the lecture and look through the data yourself to see if other ideas come to mind! Greater than 80% test accuracy is achievable without modifying the model at all. If you choose to drop/add features to `X` or renormalize some values, then you'll want to apply these operations to `X_test` as well.

# %%
## TODO: find my_X, my_y such that train_evaluate_model(my_X, my_y, X_test, y_test)
## reports better (higher) performance.

# %% [markdown]
# # Ideas for solutions
#
# Here is one way to about this exercise, but there are many other good ideas out there.
# We first break down the accuracies per class, since this is key step in the computation of balanced accuracy.

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(y_test, predictions)
print(f"Per-class accuracies: {matrix.diagonal()/matrix.sum(axis=1)}")
# Out:
# Per-class accuracies: [0.01169591 0.86765513 0.84846827]

# %% [markdown]
# Above we see that our model has extremely poor accuracy on class 0.
# Next we look at the standard deviation of each feature to see if anything looks abnormal.

# %%
print(f"Standard-deviation of each feature: {np.apply_along_axis(np.std, 0, X)}")
# Out:
# Standard-deviation of each feature: [ 1.02232649  1.57979752  1.61943279  1.11450537  1.12908644 99.99614065]

# %% [markdown]
# Here we see the last feature has some extreme values, so we simply consider dropping it from the data.

# %%
feature_to_drop = X.shape[1] - 1
X = np.delete(X, feature_to_drop, axis=1)
X_test = np.delete(X_test, feature_to_drop, axis=1)

# %%
predictions = train_evaluate_model(X, y, X_test, y_test)
# Out:
# Balanced accuracy = 0.6971385953816448

# %% [markdown]
# We this simple change already provided significant model improvement. Now we study the distribution of classes in the data and see that class 0 appears to be somewhat rare.

# %%
for k in range(max(y)+1):
    print(f"number of examples labeled as class {k}: {np.sum(y==k)}")

rare_class = 0
# Out:
# number of examples labeled as class 0: 178
# number of examples labeled as class 1: 1856
# number of examples labeled as class 2: 1836

# %% [markdown]
# We next try dropping outliers from the data. Here we avoid dropping examples from this rare class to avoid making it even rare.

# %%
from cleanlab.outlier import OutOfDistribution

n_outlier = 100  # try different values to determine good one

knn = sklearn.neighbors.NearestNeighbors(n_neighbors=10).fit(X)
ood = OutOfDistribution({"knn": knn})  # find outliers based on Euclidean nearest neighbors rather than cleanlab's cosine distance default
ood_scores = ood.score(features=X)
outlier_examples = np.argsort(ood_scores)[:n_outlier]
outlier_examples = [out for out in outlier_examples if y[out] != rare_class]  # do not delete rare-class examples

X = np.delete(X, outlier_examples, axis=0)
y =  np.delete(y, outlier_examples)

# %%
predictions = train_evaluate_model(X, y, X_test, y_test)
# Out:
# Balanced accuracy = 0.7001792012008629

# %% [markdown]
# Finally we try up-sampling examples from the rare class so it is more prevalent in the dataset.

# %%
n_upsample = 10

rareclass_X = X[y == rare_class,:]
for n in range(n_upsample):
    X = np.concatenate((X, rareclass_X + 0.001*np.random.rand(rareclass_X.shape[0],rareclass_X.shape[1])))

y = np.concatenate((y, np.array([rare_class]*int(n_upsample*np.sum(y==rare_class)))))

# %%
predictions = train_evaluate_model(X, y, X_test, y_test)
# Out:
# Balanced accuracy = 0.8373993250881112

# %% [markdown]
# With these tricks we have improved the accuracy of our model quite a bit! And this was all accomplished by improving the training data only without any change to the model. You could achieve further accuracy gains by tinkering with the model and its training procedure.
